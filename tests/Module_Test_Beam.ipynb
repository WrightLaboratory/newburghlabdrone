# %%
## Test script for importing the beam model module and seeing if things work ok...
    # Things seem to work fine, all fxns working normally...
import numpy as np
from matplotlib.pyplot import *
from newburghlabdrone.dronehacks.Bicolog_Beam_Model import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-dcf8f6cd16da> in <module>
#       3 import numpy as np
#       4 from matplotlib.pyplot import *
# ----> 5 from newburghlabdrone.dronehacks.Bicolog_Beam_Model import *
#
# ModuleNotFoundError: No module named 'newburghlabdrone'

# %%
data=Bicolog_Beam_Model.Bicolog_Beam()
# Out:
# Initialized Antenna Mapping Class: "Beam" loading file "data_S21.csv"

# %%
data.Plot_Beam_Profiles(Polarization='E')
data.Plot_Beam_Profiles(Polarization='H')

# %%
data.Plot_Beam_pcolormesh()
# Out:
# /Users/wct9/python/dronehacks/Bicolog_Beam_Model.py:114: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im2=ax2.pcolormesh(TH[:,60:],R[:,60:],self.D_ptf_t[:,60:,Freq_ind],shading='auto')

# %%
## Test Interpolation Function:
tAZ=np.linspace(3,243,250)
tAL=np.linspace(0.2,13,250)
tFF=np.linspace(455e6,777e6,1000)

data.Interpolate_D_ptf(Az_arr=tAZ,Alt_arr=tAL,Freq_arr=tFF)
data.D_ptf_interp.shape
# Out:
# (250, 1000)

# %%
plot(data.D_ptf_interp[0])
plot(data.D_ptf_interp[70])
plot(data.D_ptf_interp[120])
plot(data.D_ptf_interp[190])
plot(data.D_ptf_interp[-1])
